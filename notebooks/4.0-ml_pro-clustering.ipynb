# %%
import pandas as pd

from sklearn.cluster import MeanShift

# %%
df = pd.read_csv('../ml_pro/data/candy.csv')
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %% [markdown]
# Applying MeanShift (We don't know the number of clusters). we drop competitorname for been a descriptive name. We drop winpercent because it is a target

# %%
X = df.drop(['competitorname','winpercent'], axis=1)

meanshift = MeanShift().fit(X)
print(max(meanshift.labels_))
# Out:
# 1

# %% [markdown]
# Meanshift had clustered the dataset in 2 labels (0,1)

# %%
print(meanshift.cluster_centers_)
# Out:
# [[0.15384615 0.67307692 0.09615385 0.01923077 0.         0.
#   0.28846154 0.         0.67307692 0.42921153 0.34925    0.26923077]
#  [1.         0.         0.32258065 0.38709677 0.16129032 0.22580645
#   0.         0.61290323 0.29032258 0.54070967 0.67661291 1.67741935]]

# %%
df['meanshift'] = meanshift.labels_
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent  meanshift
# 0   66.971725          1
# 1   67.602936          1
# 2   32.261086          0
# 3   46.116505          0
# ...

# %%
df[df['meanshift']==0]
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 2                      One dime          0       0        0               0
# 3                   One quarter          0       0        0               0
# 4                     Air Heads          0       1        0               0
# 7            Boston Baked Beans          0       0        0               1
# 8                    Candy Corn          0       0        0               0
# 9            Caramel Apple Pops          0       1        1               0
# 10              Charleston Chew          1       0        0               0
# 11   Chewey Lemonhead Fruit Mix          0       1        0               0
# 12                     Chiclets          0       1        0               0
# 13                         Dots          0       1        0               0
# 14                     Dum Dums          0       1        0               0
# ...

# %%
df[df['meanshift']==1]
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                     100 Grand          1       0        1               0
# 1                  3 Musketeers          1       0        0               0
# 5                    Almond Joy          1       0        0               1
# 6                     Baby Ruth          1       0        1               1
# 23            HersheyÕs Krackel          1       0        0               0
# 24     HersheyÕs Milk Chocolate          1       0        0               0
# 25       HersheyÕs Special Dark          1       0        0               0
# 27                 Junior Mints          1       0        0               0
# 28                      Kit Kat          1       0        0               0
# 32          Peanut butter M&MÕs          1       0        0               1
# 33                        M&MÕs          1       0        0               0
# ...

# %%
df[df['meanshift']==2]
# Out:
# Empty DataFrame
# Columns: [competitorname, chocolate, fruity, caramel, peanutyalmondy, nougat, crispedricewafer, hard, bar, pluribus, sugarpercent, pricepercent, winpercent, meanshift]
# Index: []

# %% [markdown]
# The groups might had been selected based in its chocolate base

# %% [markdown]
# Applying Batch K-Means (We want 4 clusters). We drop competitorname for been a descriptive name. We drop winpercent because it is a target

# %%
from sklearn.cluster import MiniBatchKMeans

# %%
df = pd.read_csv('../ml_pro/data/candy.csv')
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
X = df.drop(['competitorname','winpercent'], axis=1)

kmeans = MiniBatchKMeans(n_clusters=4, batch_size=8).fit(X)
print(len(kmeans.cluster_centers_))
# Out:
# 4

# %%
df['kmeans'] = kmeans.predict(X)
df.head()
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent  kmeans
# 0   66.971725       1
# 1   67.602936       1
# 2   32.261086       0
# 3   46.116505       0
# ...

# %%
df[df['kmeans']==0]
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 2                      One dime          0       0        0               0
# 3                   One quarter          0       0        0               0
# 4                     Air Heads          0       1        0               0
# 9            Caramel Apple Pops          0       1        1               0
# 11   Chewey Lemonhead Fruit Mix          0       1        0               0
# 12                     Chiclets          0       1        0               0
# 13                         Dots          0       1        0               0
# 15                  Fruit Chews          0       1        0               0
# 18            Haribo Gold Bears          0       1        0               0
# 20            Haribo Sour Bears          0       1        0               0
# 21           Haribo Twin Snakes          0       1        0               0
# ...

# %%
df[df['kmeans']==1]
# Out:
#                  competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 0                     100 Grand          1       0        1               0
# 1                  3 Musketeers          1       0        0               0
# 5                    Almond Joy          1       0        0               1
# 6                     Baby Ruth          1       0        1               1
# 10              Charleston Chew          1       0        0               0
# 23            HersheyÕs Krackel          1       0        0               0
# 24     HersheyÕs Milk Chocolate          1       0        0               0
# 25       HersheyÕs Special Dark          1       0        0               0
# 28                      Kit Kat          1       0        0               0
# 36                    Milky Way          1       0        1               0
# 37           Milky Way Midnight          1       0        1               0
# ...

# %%
df[df['kmeans']==2]
# Out:
#                 competitorname  chocolate  fruity  caramel  peanutyalmondy  \
# 14                    Dum Dums          0       1        0               0
# 16                     Fun Dip          0       1        0               0
# 17                  Gobstopper          0       1        0               0
# 26                  Jawbusters          0       1        0               0
# 30                   Lemonhead          0       1        0               0
# 41                       Nerds          0       1        0               0
# 49                   Pop Rocks          0       1        0               0
# 55                    Ring pop          0       1        0               0
# 57           Root Beer Barrels          0       0        0               0
# 58                       Runts          0       1        0               0
# 63              Smarties candy          0       1        0               0
# ...

# %%
df[df['kmeans']==3]
# Out:
#           competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 7     Boston Baked Beans          0       0        0               1       0
# 8             Candy Corn          0       0        0               0       0
# 19     Haribo Happy Cola          0       0        0               0       0
# 22      HersheyÕs Kisses          1       0        0               0       0
# 27          Junior Mints          1       0        0               0       0
# 32   Peanut butter M&MÕs          1       0        0               1       0
# 33                 M&MÕs          1       0        0               0       0
# 35             Milk Duds          1       0        1               0       0
# 47           Peanut M&Ms          1       0        0               1       0
# 48          Pixie Sticks          0       0        0               0       0
# 51    ReeseÕs Miniatures          1       0        0               1       0
# ...

# %% [markdown]
# The 4 cluster might be
#
# 0: Fruity-soft candies
#
#
# 1: Chocolate bars
#
#
# 2: Fruity-hard candies
#
#
# 3: Chocolate dragee
